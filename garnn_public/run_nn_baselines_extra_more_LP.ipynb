# %%
def select_conf(version, dataset, seed, method):
    if dataset == 'ohio':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [ 'bolus', 'meal',  'basis_heart_rate', 'basis_steps'],
            
            'time_attri_list' : [],     

            'model_name': method, 


            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,

            
            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'arises':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': ['bolus', 'meal',  'HR'],
            'time_attri_list' : [],     
            'model_name': method, 


            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,


            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'shanghai_t2dm':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['bolus', 'meal'], 
            'time_attri_list' : [],  

            'model_name':method, 

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 8,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,

        }
    elif dataset == 'shanghai_t1dm':

        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,


            'attri_list': ['bolus', 'meal'],
            'time_attri_list' : [],    

            'model_name':method, 

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,

            'epochs': 20,
            'local_epochs': 500,
            'tuning_epochs': 0, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,

            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,
        }
    return CONF

# %%
for method in ['LP']:
    print(f'############################### {method} #############################')
    for dataset in ['shanghai_t1dm', 'ohio', 'arises', 'shanghai_t2dm', ]:
        for seed in [1, 10, 20, 100]:
            
            print(f'----------------{seed=}--{dataset=}------------------------')
            from gat_mem_org_log.train import *
            random.seed(seed)
            np.random.seed(seed)
            torch.manual_seed(seed)
            torch.cuda.manual_seed(seed)
            torch.backends.cudnn.deterministic = True
            torch.backends.cudnn.benchmark = False
            os.environ['PYTHONHASHSEED'] = str(seed)

            version = 'nips_23'

            CONF = select_conf(dataset=dataset, version=version, seed=seed, method=method)
            pid2model = train(CONF)
            print('end')
# Out:
# ############################### LP #############################
# ----------------seed=1--dataset='shanghai_t1dm'------------------------
# global_loop: 100%|██████████| 20/20 [02:09<00:00,  6.48s/it]
#
#  Results after 20 global rounds of training:
# rmse, 17.60920, 4.42327
# mape, 11.68286, 4.80649
# mae, 13.63734, 3.88658
# grmse, 21.74492, 6.40067
# time_lag, -3.75000, 6.49519
# [12.497678006990188, 12.236790600049227, 14.22988113836212, 16.173432707286025, 23.837071834693617, 20.147736210653107, 12.666428680861221, 16.54071385532529, 21.644670481527463, 17.957324832410833, 16.903564691140687, 26.475160869509484]
# tune_loop: 0it [00:00, ?it/s]
#
#  Results after 0 of fine tuning:
# rmse, 17.60920, 4.42327
# mape, 11.68286, 4.80649
# mae, 13.63734, 3.88658
# grmse, 21.74492, 6.40067
# time_lag, -3.75000, 6.49519
# [12.497678006990188, 12.236790600049227, 14.22988113836212, 16.173432707286025, 23.837071834693617, 20.147736210653107, 12.666428680861221, 16.54071385532529, 21.644670481527463, 17.957324832410833, 16.903564691140687, 26.475160869509484]
# models have been saved...
# end
# ----------------seed=10--dataset='shanghai_t1dm'------------------------
# exists.... don't rewrite
# end
# ----------------seed=20--dataset='shanghai_t1dm'------------------------
# exists.... don't rewrite
# end
# ----------------seed=100--dataset='shanghai_t1dm'------------------------
# exists.... don't rewrite
# end
# ----------------seed=1--dataset='ohio'------------------------
# exists.... don't rewrite
# end
# ----------------seed=10--dataset='ohio'------------------------
# exists.... don't rewrite
# end
# ----------------seed=20--dataset='ohio'------------------------
# exists.... don't rewrite
# end
# ----------------seed=100--dataset='ohio'------------------------
# exists.... don't rewrite
# end
# ----------------seed=1--dataset='arises'------------------------
# exists.... don't rewrite
# end
# ----------------seed=10--dataset='arises'------------------------
# exists.... don't rewrite
# end
# ----------------seed=20--dataset='arises'------------------------
# exists.... don't rewrite
# end
# ----------------seed=100--dataset='arises'------------------------
# exists.... don't rewrite
# end
# ----------------seed=1--dataset='shanghai_t2dm'------------------------
# exists.... don't rewrite
# end
# ----------------seed=10--dataset='shanghai_t2dm'------------------------
# exists.... don't rewrite
# end
# ----------------seed=20--dataset='shanghai_t2dm'------------------------
# global_loop: 100%|██████████| 30/30 [03:18<00:00,  6.61s/it]
#
#  Results after 30 global rounds of training:
# rmse, 14.74085, 3.91902
# mape, 8.56416, 2.87797
# mae, 10.67934, 2.94376
# grmse, 17.53279, 4.99705
# time_lag, -2.70000, 6.14085
# [14.509871181176488, 11.094277812598055, 17.088858453739768, 14.48331096078237, 18.742036883252663, 17.813887692656046, 10.988969994856276, 14.19595044916942, 13.342227893647134, 14.576632865926472, 21.54247541649549, 21.80683086361824, 20.622478539054175, 14.988679301464437, 10.707744498087733, 18.699441927981937, 13.22381941892788, 14.999439483342474, 16.416575991514073, 18.939325729339767, 16.327429710076842, 20.559130731753044, 10.128530381331087, 23.74730273540621, 6.5194955576839035, 14.712602696347982, 18.65995140993389, 13.83415133957023, 8.567469581748142, 11.80785847859746, 11.882194829032139, 15.789473221092887, 16.952464344846188, 13.626057715001028, 13.707808247783737, 6.408393910505739, 12.745037833599508, 17.371414802660542, 12.57794909620789, 12.250768520615477, 14.766494580049024, 16.94124817988858, 25.03310308371697, 16.238902836461314, 15.753030636774756, 16.582545173867594, 12.794596151259645, 6.537261094930431, 13.666451491235927, 17.943135615679225, 16.21688238133094, 11.504238508571934, 19.086656217280193, 15.65196793830721, 10.92936220700701, 10.47567037472088, 9.569925454545945, 17.80004190161413, 14.019264046457534, 11.589094599987565, 10.155884909303355, 14.975128917107337, 17.42090191368771, 12.140618087393463, 18.979890320343415, 15.861809965475548, 12.534105693745852, 10.335876972139477, 14.2972405392136, 21.842348678674217, 14.599020290163898, 14.764312524340788, 14.786768715738216, 11.918605051024414, 10.81245060727519, 12.342196673428354, 14.515621320808199, 8.5990715057917, 13.512165380916931, 18.082098337124414, 13.293946711381052, 15.081332135441226, 16.982696702958794, 12.87506103501158, 17.357391875923497, 11.219975396603623, 18.526892009699374, 10.404311357519957, 12.766478417770745, 15.62220433974083, 13.033785420127558, 18.2049372086127, 9.838503453651859, 15.986024475010195, 21.1665670237361, 29.47793012166581, 12.99891599390509, 13.641699400163239, 12.150441328910842, 10.921808288981708]
# tune_loop: 100%|██████████| 10/10 [01:25<00:00,  8.53s/it]
#
#  Results after 10 of fine tuning:
# rmse, 14.63713, 3.88484
# mape, 8.49939, 2.81452
# mae, 10.59849, 2.89134
# grmse, 17.38580, 4.94930
# time_lag, -2.70000, 6.14085
