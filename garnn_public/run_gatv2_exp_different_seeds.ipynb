# %%
def select_conf(version, dataset, seed):
    if dataset == 'ohio':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [ 'meal', 'bolus', 'basal', 'finger_stick',
            'basis_skin_temperature', 'basis_gsr', 'basis_sleep', 'acceleration',
            'exercise', 'sleep', 'work', 'basis_steps', 'basis_heart_rate', 'basis_air_temperature'],
            
            'time_attri_list' : ['timestamp'],     
            'model_name':'gatv2_exp', 

            'hidden_dim': 512,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,

            # 'epochs': 2,
            # 'local_epochs': 2,
            # 'tuning_epochs': 2, 
            # 'tuning_local_epochs': 2,

            'weight_decay': 1e-4,
            'batch_size': 128,
            'nhead': 1,
            'num_layers':2,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,

            
            'interval': 5,
            'log_epoch_vari_imp': True,
        }
    elif dataset == 'arises':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [
            'meal', 'bolus', 'basal', 'correction_bolus',
            'finger_stick', 'EDA', 'SCL', 'SCR', 'HR', 'TEMP', 'ACC', 'RMSSD', 'SDNN',
            'medianNNI', 'CVNNI', 'CVSD', 'pNNX', 'meanHR', 'minHR', 'maxHR', 'VLF',
            'LF', 'HF', 'LHR', ],
            'time_attri_list' : ['timestamp'],     
            'model_name':'gatv2_exp', 

            'hidden_dim': 512,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'nhead': 1,
            'num_layers':2,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,


            'interval': 5,
            'log_epoch_vari_imp': True,

        }
    elif dataset == 'shanghai_t2dm':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],     
            'model_name':'gatv2_exp', 

            'hidden_dim': 256,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'nhead': 1,
            'num_layers':2,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': True,

        }
    elif dataset == 'shanghai_t1dm':

        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],     
            'model_name':'gatv2_exp', 

            'hidden_dim': 256,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 20,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 80,

            # 'epochs': 2,
            # 'local_epochs': 5,
            # 'tuning_epochs': 2, 
            # 'tuning_local_epochs': 8,

            'weight_decay': 1e-4,
            'batch_size': 128,
            'nhead': 1,
            'num_layers':2,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': True,

        }

    return CONF

# %%
for dataset in ['ohio', 'shanghai_t1dm', 'arises', 'shanghai_t2dm', ]:
    for seed in [10, 20, 100]:
        
        print(f'----------------{seed=}--{dataset=}------------------------')
        from gat_mem_org_log.train import *
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
        os.environ['PYTHONHASHSEED'] = str(seed)

        version = 'nips_23'
        CONF = select_conf(dataset=dataset, version=version, seed=seed)
        pid2model = train(CONF)
        print('end')
# Out:
# ----------------seed=10--dataset='ohio'------------------------
# global_loop: 100%|██████████| 30/30 [52:42<00:00, 105.43s/it]
#
#  Results after 30 global rounds of training:
# rmse, 20.36504, 2.56826
# mape, 9.48352, 1.56818
# mae, 14.46301, 1.62198
# grmse, 26.52012, 3.55538
# time_lag, -6.72917, 4.80994
# [20.025851517573635, 20.10547747777642, 19.20940289722637, 24.771548976030445, 17.790270188473986, 20.55676523492517, 23.602057726101975, 17.367480070916216, 17.89120325211789, 21.681876297166372, 24.15501442102007, 17.223570991669472]
# tune_loop: 100%|██████████| 30/30 [1:28:11<00:00, 176.39s/it]
#
#  Results after 30 of fine tuning:
# rmse, 19.24285, 2.59340
# mape, 9.04954, 1.79404
# mae, 13.37540, 1.76247
# grmse, 24.12610, 3.56649
# time_lag, -6.17361, 4.43347
# [18.47767735801432, 18.82868337475972, 16.653599512087002, 23.419911369071325, 16.784008516874962, 20.319926526995612, 22.402092754151898, 15.944801961602614, 17.45643031173658, 21.128361361179756, 22.949048204153534, 16.54963293676923]
# models have been saved...
# end
# ----------------seed=20--dataset='ohio'------------------------
# global_loop: 100%|██████████| 30/30 [59:01<00:00, 118.06s/it]
#
#  Results after 30 global rounds of training:
# rmse, 19.58604, 2.40310
# mape, 9.61849, 1.70841
# mae, 14.04430, 1.53342
# grmse, 23.49183, 3.11801
# time_lag, -7.33333, 4.72202
# [19.32988462710695, 18.323750343752128, 16.421525626635606, 22.581039631294175, 17.356592760558144, 20.965715305272052, 21.98200183197644, 18.031937134870937, 17.245527931686468, 22.056178411128155, 23.595541374461114, 17.14272755165164]
# tune_loop: 100%|██████████| 30/30 [1:27:35<00:00, 175.17s/it]
#
#  Results after 30 of fine tuning:
# rmse, 18.94515, 2.42387
# mape, 9.09982, 1.78312
# mae, 13.35034, 1.63340
# grmse, 23.64121, 3.20780
# time_lag, -6.18056, 4.66243
# [18.80178071374657, 18.216170218294376, 15.591097007850445, 22.64810872044907, 16.5985521167675, 20.226999289171406, 21.054256286168645, 16.501927118758356, 17.161326840195535, 21.476357168671043, 22.46020039551385, 16.60504191479767]
# models have been saved...
# end
# ----------------seed=100--dataset='ohio'------------------------
# global_loop: 100%|██████████| 30/30 [54:18<00:00, 108.62s/it]
#
#  Results after 30 global rounds of training:
# rmse, 19.32780, 2.44127
# mape, 9.20338, 1.68136
# mae, 13.56377, 1.61654
# grmse, 23.64714, 3.12303
# time_lag, -7.12500, 5.16986
# [18.81989008839991, 18.317525440988202, 16.759219237284277, 22.761566910532682, 16.881854438341296, 20.62158840747399, 21.82905680388563, 17.173640541345897, 17.01168242318165, 21.426216737256137, 23.49178219221365, 16.839597738721466]
# tune_loop: 100%|██████████| 30/30 [1:28:48<00:00, 177.60s/it]
#
#  Results after 30 of fine tuning:
# rmse, 19.26393, 2.32073
# mape, 9.11876, 1.74425
# mae, 13.48171, 1.62078
# grmse, 24.07809, 3.11899
# time_lag, -6.52778, 5.04830
# [18.823884377218082, 18.67762071638141, 16.981192563507022, 23.235142051897917, 16.624013312179333, 20.287089725278104, 21.722315916795395, 16.914780585218768, 17.59018076167825, 20.884382686245406, 22.688269399832482, 16.738267120034877]
# c:\code\fornips23\gat_mem_org_log\log.py:106: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize = (20, 15))
# models have been saved...
# end
# ----------------seed=10--dataset='shanghai_t1dm'------------------------
# global_loop: 100%|██████████| 20/20 [09:15<00:00, 27.79s/it]
#
#  Results after 20 global rounds of training:
# rmse, 14.91543, 3.65618
# mape, 10.09675, 4.65671
# mae, 11.44336, 3.18372
# grmse, 18.34688, 6.01634
# time_lag, -1.25000, 4.14578
# [10.95427180883405, 10.096883281585121, 11.6670951401276, 14.263004726669896, 22.324996227165833, 15.090665829923797, 11.673976969364382, 13.246007353743606, 20.143787026319522, 16.634298606695708, 14.530699754367046, 18.359420711379265]
# tune_loop: 100%|██████████| 10/10 [08:45<00:00, 52.56s/it]
#
#  Results after 10 of fine tuning:
# rmse, 14.47660, 3.57022
# mape, 9.53225, 4.58888
# mae, 10.98281, 3.09622
# grmse, 17.63207, 5.79378
# time_lag, -1.25000, 4.14578
# [11.012568489407306, 10.159756756371326, 11.643855728267296, 13.299584082503412, 21.415298042156103, 14.680732109253675, 11.748856509144238, 12.043282335562116, 20.919672330839397, 14.973753282110522, 14.254165843587073, 17.567695690806055]
# models have been saved...
# end
# ----------------seed=20--dataset='shanghai_t1dm'------------------------
# global_loop: 100%|██████████| 20/20 [09:15<00:00, 27.77s/it]
#
#  Results after 20 global rounds of training:
# rmse, 13.84713, 2.93869
# mape, 8.84396, 3.15242
# mae, 10.62330, 2.42635
# grmse, 17.02131, 4.74391
# time_lag, -1.25000, 4.14578
# [10.579494190492293, 9.859473274817267, 13.232019856669831, 13.315255752955013, 20.500770368290052, 15.721306716150577, 11.397227944091068, 11.832490989541387, 13.947016046158293, 12.878447728416445, 15.03029777064376, 17.87178832325108]
# tune_loop: 100%|██████████| 10/10 [08:54<00:00, 53.45s/it]
#
#  Results after 10 of fine tuning:
# rmse, 13.72696, 2.69880
# mape, 8.70041, 3.26767
# mae, 10.36156, 2.27440
# grmse, 16.53390, 4.17278
# time_lag, -1.25000, 4.14578
# [10.382547597612987, 10.126939752582782, 13.19527549580365, 13.962692141939746, 19.273135068056845, 14.259704497754546, 11.4490968039821, 10.788499600630873, 16.07010930535127, 13.208224098564145, 15.022389804374347, 16.984880792549276]
# models have been saved...
# end
# ----------------seed=100--dataset='shanghai_t1dm'------------------------
# global_loop: 100%|██████████| 20/20 [09:31<00:00, 28.59s/it]
#
#  Results after 20 global rounds of training:
# rmse, 13.61084, 2.58557
# mape, 8.54422, 2.74858
# mae, 10.40934, 2.17814
# grmse, 16.23322, 3.84867
# time_lag, -2.50000, 5.59017
# [10.995937984576146, 10.149971767442647, 11.494044212902788, 13.138463263218622, 18.44210499298455, 14.66158004177207, 11.796194620280358, 12.402140746370097, 14.169625066886308, 12.640830209242834, 14.859318008072883, 18.57991541519868]
# tune_loop: 100%|██████████| 10/10 [08:52<00:00, 53.28s/it]
#
#  Results after 10 of fine tuning:
# rmse, 13.60759, 2.74952
# mape, 8.63825, 3.36419
# mae, 10.36626, 2.38636
# grmse, 16.34767, 4.26191
# time_lag, -1.25000, 4.14578
# [11.216436886146083, 10.084348096832334, 12.02897959503034, 12.867826074204476, 18.709930329103898, 14.48365441168725, 11.519876303538512, 10.29052019619043, 16.82537462290727, 12.777493024961105, 15.136873991139412, 17.349729754627123]
# models have been saved...
# end
# ----------------seed=10--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 [58:10<00:00, 116.36s/it]
#
#  Results after 30 global rounds of training:
# rmse, 20.82190, 4.11142
# mape, 10.61099, 2.48116
# mae, 15.30592, 2.98496
# grmse, 26.24162, 5.59566
# time_lag, -9.89583, 5.91736
# [23.84160607374808, 19.934062601653498, 23.577083051447303, 15.08689532012437, 20.406928946400473, 23.363877858228474, 28.71905603754239, 18.562444102399002, 23.532076108091935, 16.841167074976294, 22.427189320126168, 13.570360287948384]
# tune_loop: 100%|██████████| 30/30 [1:35:17<00:00, 190.57s/it]
#
#  Results after 30 of fine tuning:
# rmse, 20.17061, 3.91132
# mape, 9.75034, 2.28739
# mae, 14.57859, 2.66781
# grmse, 25.35271, 5.39516
# time_lag, -9.82639, 5.83199
# [23.45069680551225, 19.766633960167177, 21.592566362504034, 14.462609324788017, 19.473274109430484, 22.64444600909004, 27.60290472253045, 18.542983973424338, 23.095852354829724, 15.93172143632962, 21.93931741603737, 13.544343810889405]
# models have been saved...
# end
# ----------------seed=20--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 [57:38<00:00, 115.27s/it]
#
#  Results after 30 global rounds of training:
# rmse, 20.61459, 3.84322
# mape, 10.23077, 2.28575
# mae, 15.14735, 2.76724
# grmse, 26.45926, 5.31329
# time_lag, -9.47917, 5.89532
# [23.595648723268344, 19.938474242703556, 22.77965181079583, 15.781144124799548, 19.712299918233953, 22.681875325063373, 27.938320344149965, 18.949893131810303, 23.700070872784327, 16.286574300367963, 22.27689818783337, 13.734218349149302]
# tune_loop: 100%|██████████| 30/30 [1:34:05<00:00, 188.17s/it]
#
#  Results after 30 of fine tuning:
# rmse, 19.88471, 3.79294
# mape, 9.60533, 2.26935
# mae, 14.36125, 2.58309
# grmse, 25.01262, 5.14020
# time_lag, -9.89583, 6.00474
# [22.65703123653064, 19.81419350880315, 21.404031591253435, 14.141160750382696, 18.90487227030748, 21.94731420538919, 27.10375031706867, 18.373039296699034, 22.952997361796236, 15.87458620508318, 21.91598908086464, 13.527513512326346]
# models have been saved...
# end
# ----------------seed=100--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 [56:52<00:00, 113.75s/it]
#
#  Results after 30 global rounds of training:
# rmse, 21.33484, 3.94508
# mape, 10.12517, 2.07745
# mae, 15.58105, 2.74389
# grmse, 27.81681, 5.71341
# time_lag, -10.31250, 6.41704
# [24.811747272902306, 20.320468689326688, 22.71446185459277, 16.784403982299033, 21.144294189161588, 23.614495742651112, 29.041644482670268, 19.843618509652938, 23.947456062293313, 15.940565824146436, 23.20937547335734, 14.64557784587051]
# tune_loop: 100%|██████████| 30/30 [1:32:47<00:00, 185.57s/it]
#
#  Results after 30 of fine tuning:
# rmse, 19.96331, 3.66660
# mape, 9.65175, 2.24903
# mae, 14.42474, 2.53015
# grmse, 25.14424, 4.90442
# time_lag, -9.82639, 5.83199
# [23.015927314715128, 19.799620283705096, 21.458649370650054, 14.279964063583163, 18.99510772361243, 22.429760291374397, 26.43860813280457, 18.485061800427527, 23.02919210404142, 15.612386021682882, 21.90201108573387, 14.113385041481068]
# models have been saved...
# end
# ----------------seed=10--dataset='shanghai_t2dm'------------------------
# global_loop: 100%|██████████| 30/30 [17:03<00:00, 34.13s/it]
#
#  Results after 30 global rounds of training:
# rmse, 12.23520, 3.03899
# mape, 7.33408, 2.85439
# mae, 9.00616, 2.43639
# grmse, 13.92823, 3.76139
# time_lag, -1.20000, 4.06940
