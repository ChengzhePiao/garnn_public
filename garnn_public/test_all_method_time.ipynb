# %%
def get_conf(dataset, method):
    
    version = 'nips_23'
    
    num_layers = 1 if 'layer_1' in method else 2
    if dataset == 'ohio':
        CONF = {
        'data_path':f'../../code_data/{dataset}/{version}/',
        'log_path': f'../../code_log/{version}/{dataset}',
        'dataset': dataset,
        'n_prev' : 48,
        'pred_window' : 6,
        'seq_len': 48,
        'mix_test_and_valid_2018': False,

        'attri_list': [ 'meal', 'bolus', 'basal', 'finger_stick',
        'basis_skin_temperature', 'basis_gsr', 'basis_sleep', 'acceleration',
        'exercise', 'sleep', 'work', 'basis_steps', 'basis_heart_rate', 'basis_air_temperature'],
        
        'time_attri_list' : ['timestamp'],     
        'model_name':method, 

        'hidden_dim': 512,

        'lr': 1e-3,  # 1e-4
        'tuning_lr':1e-5,
        'epochs': 30,
        'local_epochs': 500,
        'tuning_epochs': 30, 
        'tuning_local_epochs': 80,
        'weight_decay': 1e-4,
        'batch_size': 128,
        'nhead': 1,
        'num_layers':num_layers,
        'device': 'cuda',


        'print_every':2,
        'comments': 'pred_6_all_features',
        'save_model': True,
        'all_edges': True,

        
        'interval': 5,
        'log_epoch_vari_imp': True,
    }
    
    elif dataset == 'arises':
        CONF = {
        'data_path':f'../../code_data/{dataset}/{version}/',
        'log_path': f'../../code_log/{version}/{dataset}',
        'dataset': dataset,
        'n_prev' : 48,
        'pred_window' : 6,
        'seq_len': 48,
        'mix_test_and_valid_2018': False,

        'attri_list': [
        'meal', 'bolus', 'basal', 'correction_bolus',
        'finger_stick', 'EDA', 'SCL', 'SCR', 'HR', 'TEMP', 'ACC', 'RMSSD', 'SDNN',
        'medianNNI', 'CVNNI', 'CVSD', 'pNNX', 'meanHR', 'minHR', 'maxHR', 'VLF',
        'LF', 'HF', 'LHR', ],
        'time_attri_list' : ['timestamp'],     
        'model_name':method, 

        'hidden_dim': 512,

        'lr': 1e-3,  # 1e-4
        'tuning_lr':1e-5,
        'epochs': 30,
        'local_epochs': 500,
        'tuning_epochs': 30, 
        'tuning_local_epochs': 80,
        'weight_decay': 1e-4,
        'batch_size': 128,
        'nhead': 1,
        'num_layers':num_layers,
        'device': 'cuda',


        'print_every':2,
        'comments': 'pred_6_all_features',
        'save_model': True,
        'all_edges': True,


        'interval': 5,
        'log_epoch_vari_imp': True,
    }
        
    elif dataset == 'shanghai_t1dm':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],     
            'model_name':method, 

            'hidden_dim': 256,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 20,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 80,

            # 'epochs': 2,
            # 'local_epochs': 5,
            # 'tuning_epochs': 2, 
            # 'tuning_local_epochs': 8,

            'weight_decay': 1e-4,
            'batch_size': 128,
            'nhead': 1,
            'num_layers':num_layers,
            'device': 'cuda',


            'print_every':2,
            'comments': 'pred_2_all_features',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': True,
        } 
    elif dataset == 'shanghai_t2dm':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],     
            'model_name':method, 

            'hidden_dim': 256,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,

            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 80,
            # 'epochs': 2,
            # 'local_epochs': 5,
            # 'tuning_epochs': 2, 
            # 'tuning_local_epochs': 8,
            
            'weight_decay': 1e-4,
            'batch_size': 128,
            'nhead': 1,
            'num_layers':num_layers,
            'device': 'cuda',


            'print_every':2,
            'comments': 'pred_2_all_features',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': True,
        }
                
    return CONF

# %%
from gat_mem_org_log.train import *
seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

datasets = ['ohio', 'arises', 'shanghai_t1dm', 'shanghai_t2dm']


# methods = ['gatv2_exp', 'gatv2_exp_layer_1', 'gat_exp', 'gat_exp_layer_1',
#            'MNODE', 'LPSC', 'LP', 'NHiTS', 'NBEATS', 'att_f_lstm','att_t_lstm' , 'ETN-ODE', 'imv_tensor_lstm','imv_full_lstm', 'retain',  'xgboost', 'linear_regression']
methods = ['gatv2_exp_acc', 'gatv2_exp_layer_1_acc', 'gat_exp_acc', 'gat_exp_layer_1_acc',]
for dataset in datasets:
    for method in methods:


        CONF = get_conf(dataset,method)
        global_model = get_model(CONF)
        global_model.to(CONF['device'])
        data_proc = DataProcessor(CONF)
        update = Update(data_proc, CONF)
        pid2model = create_pid2model(data_proc, CONF, global_model)
        
        start_time = time.time()
        for pid in data_proc.test_pid2data_npy.keys():
            pid2model[pid].eval()
            output_dict = update.test_inference(pid2model[pid], pid)
        predict_time = time.time() - start_time

        np.save(f'./results/test_time/{dataset}_{method}.npy', [predict_time])
        print(dataset, method, predict_time)
# Out:
# ohio gatv2_exp_acc 8.527929067611694
# ohio gatv2_exp_layer_1_acc 5.691346168518066
# ohio gat_exp_acc 11.190320253372192
# ohio gat_exp_layer_1_acc 6.985512018203735
# arises gatv2_exp_acc 10.232501983642578
# arises gatv2_exp_layer_1_acc 6.347712993621826
# arises gat_exp_acc 12.98982048034668
# arises gat_exp_layer_1_acc 7.734090805053711
# shanghai_t1dm gatv2_exp_acc 0.4095475673675537
# shanghai_t1dm gatv2_exp_layer_1_acc 0.3160667419433594
# shanghai_t1dm gat_exp_acc 0.4964561462402344
# shanghai_t1dm gat_exp_layer_1_acc 0.31453800201416016
# shanghai_t2dm gatv2_exp_acc 3.0031371116638184
# shanghai_t2dm gatv2_exp_layer_1_acc 2.2667791843414307
# shanghai_t2dm gat_exp_acc 3.737766981124878
# shanghai_t2dm gat_exp_layer_1_acc 2.642104148864746

# %%
def get_conf(dataset, method):
    
    version = 'nips_23'
    seed = 1
    if dataset == 'ohio':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [ 'bolus', 'meal',  'basis_heart_rate', 'basis_steps'],
            
            'time_attri_list' : [],     

            'model_name': method, 


            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,

            
            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'arises':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': ['bolus', 'meal',  'HR'],
            'time_attri_list' : [],     
            'model_name': method, 


            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,


            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'shanghai_t2dm':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['bolus', 'meal'], 
            'time_attri_list' : [],  

            'model_name':method, 

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 40,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,

        }
    elif dataset == 'shanghai_t1dm':

        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,


            'attri_list': ['bolus', 'meal'],
            'time_attri_list' : [],    

            'model_name':method, 

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,

            'epochs': 20,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 40,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,

            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,
        }
    return CONF

# %%
from gat_mem_org_log.train import *
seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

datasets = ['ohio', 'arises', 'shanghai_t1dm', 'shanghai_t2dm']


# methods = ['gatv2_exp', 'gatv2_exp_layer_1', 'gat_exp', 'gat_exp_layer_1',
#            'MNODE', 'LPSC', 'LP', 'NHiTS', 'NBEATS', 'att_f_lstm','att_t_lstm' , 'ETN-ODE', 'imv_tensor_lstm','imv_full_lstm', 'retain',  'xgboost', 'linear_regression']
methods = ['MNODE', 'LPSC', 'LP']
for dataset in datasets:
    for method in methods:


        CONF = get_conf(dataset, method)
        global_model = get_model(CONF)
        global_model.to(CONF['device'])
        data_proc = DataProcessor(CONF)
        update = Update(data_proc, CONF)
        pid2model = create_pid2model(data_proc, CONF, global_model)
        start_time = time.time()
        for pid in data_proc.test_pid2data_npy.keys():

            output_dict = update.test_inference(pid2model[pid], pid)
        predict_time = time.time() - start_time

        np.save(f'./results/test_time/{dataset}_{method}.npy', [predict_time])
        print(dataset, method, predict_time)
# Out:
# ohio MNODE 3.3411476612091064
# ohio LPSC 4.487264633178711
# ohio LP 2.2965335845947266
# arises MNODE 2.983769655227661
# arises LPSC 4.632924318313599
# arises LP 2.2791666984558105
# shanghai_t1dm MNODE 0.18801522254943848
# shanghai_t1dm LPSC 0.22101807594299316
# shanghai_t1dm LP 0.1577460765838623
# shanghai_t2dm MNODE 1.4831640720367432
# shanghai_t2dm LPSC 1.7016563415527344
# shanghai_t2dm LP 1.3227708339691162

# %%
def select_conf(version, dataset, seed, method, hidden_dim):
    if dataset == 'ohio':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [ 'meal', 'bolus', 'basal', 'finger_stick',
            'basis_skin_temperature', 'basis_gsr', 'basis_sleep', 'acceleration',
            'exercise', 'sleep', 'work', 'basis_steps', 'basis_heart_rate', 'basis_air_temperature'],
            
            'time_attri_list' : ['timestamp'],     

            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,

            
            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'arises':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [
            'meal', 'bolus', 'basal', 'correction_bolus',
            'finger_stick', 'EDA', 'SCL', 'SCR', 'HR', 'TEMP', 'ACC', 'RMSSD', 'SDNN',
            'medianNNI', 'CVNNI', 'CVSD', 'pNNX', 'meanHR', 'minHR', 'maxHR', 'VLF',
            'LF', 'HF', 'LHR', ],
            'time_attri_list' : ['timestamp'],     
            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,


            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'shanghai_t2dm':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],  

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,


            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,

        }
    elif dataset == 'shanghai_t1dm':

        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,


            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],    

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,

            'epochs': 20,
            'local_epochs': 500,
            'tuning_epochs': 0, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,

            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,
        }
    return CONF

mthd_dt2hidden_dim = {
    ('imv_tensor_lstm', 'ohio') : 512//16,
    ('imv_tensor_lstm', 'arises') : 512//26,
    ('imv_tensor_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_tensor_lstm', 'shanghai_t2dm') : 256//10,

    ('imv_full_lstm', 'ohio') : 512//16,
    ('imv_full_lstm', 'arises') : 512//26,
    ('imv_full_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_full_lstm', 'shanghai_t2dm') : 256//10,

    ('tgru', 'ohio') : 32*16,
    ('tgru', 'arises') : 20*26,
    ('tgru', 'shanghai_t1dm') : 25*10,
    ('tgru', 'shanghai_t2dm') : 25*10,

    ('retain', 'ohio') : 512,
    ('retain', 'arises') : 512,
    ('retain', 'shanghai_t1dm') : 256,
    ('retain', 'shanghai_t2dm') : 256,
    
    ('gat_simplev2', 'ohio') : 512,
    ('gat_simplev2', 'arises') : 512,
    ('gat_simplev2', 'shanghai_t1dm') : 256,
    ('gat_simplev2', 'shanghai_t2dm') : 256,

    ('gat_exp_layer_1', 'ohio') : 512,
    ('gat_exp_layer_1', 'arises') : 512,
    ('gat_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gat_exp_layer_1', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp_layer_1', 'ohio') : 512,
    ('gatv2_exp_layer_1', 'arises') : 512,
    ('gatv2_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gatv2_exp_layer_1', 'shanghai_t2dm') : 256,


    ('gat_simplev2_layer_1', 'ohio') : 512,
    ('gat_simplev2_layer_1', 'arises') : 512,
    ('gat_simplev2_layer_1', 'shanghai_t1dm') : 256,
    ('gat_simplev2_layer_1', 'shanghai_t2dm') : 256,

    ('gat_exp', 'ohio') : 512,
    ('gat_exp', 'arises') : 512,
    ('gat_exp', 'shanghai_t1dm') : 256,
    ('gat_exp', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp', 'ohio') : 512,
    ('gatv2_exp', 'arises') : 512,
    ('gatv2_exp', 'shanghai_t1dm') : 256,
    ('gatv2_exp', 'shanghai_t2dm') : 256,

    ('att_t_lstm', 'ohio') : 512,
    ('att_t_lstm', 'arises') : 512,
    ('att_t_lstm', 'shanghai_t1dm') : 256,
    ('att_t_lstm', 'shanghai_t2dm') : 256,
    
    ('att_f_lstm', 'ohio') : 512,
    ('att_f_lstm', 'arises') : 512,
    ('att_f_lstm', 'shanghai_t1dm') : 256,
    ('att_f_lstm', 'shanghai_t2dm') : 256,
    
    ('NHiTS', 'ohio') : 512,
    ('NHiTS', 'arises') : 512,
    ('NHiTS', 'shanghai_t1dm') : 256,
    ('NHiTS', 'shanghai_t2dm') : 256,
}

# %%
from gat_mem_org_log.train import *
seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

datasets = ['ohio', 'arises', 'shanghai_t1dm', 'shanghai_t2dm']


# methods = ['gatv2_exp', 'gatv2_exp_layer_1', 'gat_exp', 'gat_exp_layer_1',
#            'MNODE', 'LPSC', 'LP', 'NHiTS', 'NBEATS', 'att_f_lstm','att_t_lstm' , 'ETN-ODE', 'imv_tensor_lstm','imv_full_lstm', 'retain',  'xgboost', 'linear_regression']
methods = ['NHiTS']
for dataset in datasets:
    for method in methods:

        version = 'nips_23'
        CONF = select_conf(dataset=dataset, version=version, seed=seed, method=method, hidden_dim=mthd_dt2hidden_dim[(method, dataset)])
        global_model = get_model(CONF)
        global_model.to(CONF['device'])
        data_proc = DataProcessor(CONF)
        update = Update(data_proc, CONF)
        pid2model = create_pid2model(data_proc, CONF, global_model)
        start_time = time.time()
        for pid in data_proc.test_pid2data_npy.keys():

            output_dict = update.test_inference(pid2model[pid], pid)
        predict_time = time.time() - start_time

        np.save(f'./results/test_time/{dataset}_{method}.npy', [predict_time])
        print(dataset, method, predict_time)
# Out:
# ohio NHiTS 1.4251344203948975
# arises NHiTS 1.447096586227417
# shanghai_t1dm NHiTS 0.1384108066558838
# shanghai_t2dm NHiTS 1.2186405658721924

# %%
def select_conf(version, dataset, seed, method, hidden_dim):
    if dataset == 'ohio':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [ 'meal', 'bolus', 'basal', 'finger_stick',
            'basis_skin_temperature', 'basis_gsr', 'basis_sleep', 'acceleration',
            'exercise', 'sleep', 'work', 'basis_steps', 'basis_heart_rate', 'basis_air_temperature'],
            
            'time_attri_list' : ['timestamp'],     

            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,

            
            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'arises':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [
            'meal', 'bolus', 'basal', 'correction_bolus',
            'finger_stick', 'EDA', 'SCL', 'SCR', 'HR', 'TEMP', 'ACC', 'RMSSD', 'SDNN',
            'medianNNI', 'CVNNI', 'CVSD', 'pNNX', 'meanHR', 'minHR', 'maxHR', 'VLF',
            'LF', 'HF', 'LHR', ],
            'time_attri_list' : ['timestamp'],     
            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,


            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'shanghai_t2dm':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],  

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,


            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,

        }
    elif dataset == 'shanghai_t1dm':

        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,


            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],    

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,

            'epochs': 20,
            'local_epochs': 500,
            'tuning_epochs': 0, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,

            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,
        }
    return CONF
mthd_dt2hidden_dim = {
    ('imv_tensor_lstm', 'ohio') : 512//16,
    ('imv_tensor_lstm', 'arises') : 512//26,
    ('imv_tensor_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_tensor_lstm', 'shanghai_t2dm') : 256//10,

    ('imv_full_lstm', 'ohio') : 512//16,
    ('imv_full_lstm', 'arises') : 512//26,
    ('imv_full_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_full_lstm', 'shanghai_t2dm') : 256//10,

    ('tgru', 'ohio') : 32*16,
    ('tgru', 'arises') : 20*26,
    ('tgru', 'shanghai_t1dm') : 25*10,
    ('tgru', 'shanghai_t2dm') : 25*10,

    ('retain', 'ohio') : 512,
    ('retain', 'arises') : 512,
    ('retain', 'shanghai_t1dm') : 256,
    ('retain', 'shanghai_t2dm') : 256,
    
    ('gat_simplev2', 'ohio') : 512,
    ('gat_simplev2', 'arises') : 512,
    ('gat_simplev2', 'shanghai_t1dm') : 256,
    ('gat_simplev2', 'shanghai_t2dm') : 256,

    ('gat_exp_layer_1', 'ohio') : 512,
    ('gat_exp_layer_1', 'arises') : 512,
    ('gat_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gat_exp_layer_1', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp_layer_1', 'ohio') : 512,
    ('gatv2_exp_layer_1', 'arises') : 512,
    ('gatv2_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gatv2_exp_layer_1', 'shanghai_t2dm') : 256,


    ('gat_simplev2_layer_1', 'ohio') : 512,
    ('gat_simplev2_layer_1', 'arises') : 512,
    ('gat_simplev2_layer_1', 'shanghai_t1dm') : 256,
    ('gat_simplev2_layer_1', 'shanghai_t2dm') : 256,

    ('gat_exp', 'ohio') : 512,
    ('gat_exp', 'arises') : 512,
    ('gat_exp', 'shanghai_t1dm') : 256,
    ('gat_exp', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp', 'ohio') : 512,
    ('gatv2_exp', 'arises') : 512,
    ('gatv2_exp', 'shanghai_t1dm') : 256,
    ('gatv2_exp', 'shanghai_t2dm') : 256,

    ('att_t_lstm', 'ohio') : 512,
    ('att_t_lstm', 'arises') : 512,
    ('att_t_lstm', 'shanghai_t1dm') : 256,
    ('att_t_lstm', 'shanghai_t2dm') : 256,
    
    ('att_f_lstm', 'ohio') : 512,
    ('att_f_lstm', 'arises') : 512,
    ('att_f_lstm', 'shanghai_t1dm') : 256,
    ('att_f_lstm', 'shanghai_t2dm') : 256,
    
    ('NHiTS', 'ohio') : 512,
    ('NHiTS', 'arises') : 512,
    ('NHiTS', 'shanghai_t1dm') : 256,
    ('NHiTS', 'shanghai_t2dm') : 256,
    
    ('NBEATS', 'ohio') : 512,
    ('NBEATS', 'arises') : 512,
    ('NBEATS', 'shanghai_t1dm') : 256,
    ('NBEATS', 'shanghai_t2dm') : 256,
}

# %%
from gat_mem_org_log.train import *
seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

datasets = ['ohio', 'arises', 'shanghai_t1dm', 'shanghai_t2dm']


# methods = ['gatv2_exp', 'gatv2_exp_layer_1', 'gat_exp', 'gat_exp_layer_1',
#            'MNODE', 'LPSC', 'LP', 'NHiTS', 'NBEATS', 'att_f_lstm','att_t_lstm' , 'ETN-ODE', 'imv_tensor_lstm','imv_full_lstm', 'retain',  'xgboost', 'linear_regression']
methods = ['NBEATS']
for dataset in datasets:
    for method in methods:

        version = 'nips_23'
        CONF = select_conf(dataset=dataset, version=version, seed=seed, method=method, hidden_dim=mthd_dt2hidden_dim[(method, dataset)])
        global_model = get_model(CONF)
        global_model.to(CONF['device'])
        data_proc = DataProcessor(CONF)
        update = Update(data_proc, CONF)
        pid2model = create_pid2model(data_proc, CONF, global_model)
        start_time = time.time()
        for pid in data_proc.test_pid2data_npy.keys():

            output_dict = update.test_inference(pid2model[pid], pid)
        predict_time = time.time() - start_time

        np.save(f'./results/test_time/{dataset}_{method}.npy', [predict_time])
        print(dataset, method, predict_time)
# Out:
# ohio NBEATS 0.9007630348205566
# arises NBEATS 1.0111334323883057
# shanghai_t1dm NBEATS 0.11228418350219727
# shanghai_t2dm NBEATS 0.7705435752868652

# %%
def select_conf(version, dataset, seed, method, hidden_dim):
    if dataset == 'ohio':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [ 'meal', 'bolus', 'basal', 'finger_stick',
            'basis_skin_temperature', 'basis_gsr', 'basis_sleep', 'acceleration',
            'exercise', 'sleep', 'work', 'basis_steps', 'basis_heart_rate', 'basis_air_temperature'],
            
            'time_attri_list' : ['timestamp'],     

            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,

            
            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'arises':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [
            'meal', 'bolus', 'basal', 'correction_bolus',
            'finger_stick', 'EDA', 'SCL', 'SCR', 'HR', 'TEMP', 'ACC', 'RMSSD', 'SDNN',
            'medianNNI', 'CVNNI', 'CVSD', 'pNNX', 'meanHR', 'minHR', 'maxHR', 'VLF',
            'LF', 'HF', 'LHR', ],
            'time_attri_list' : ['timestamp'],     
            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,


            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'shanghai_t2dm':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],  

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,


            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,

        }
    elif dataset == 'shanghai_t1dm':

        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,


            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],    

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,

            'epochs': 20,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,

            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,
        }
    return CONF
mthd_dt2hidden_dim = {
    ('imv_tensor_lstm', 'ohio') : 512//16,
    ('imv_tensor_lstm', 'arises') : 512//26,
    ('imv_tensor_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_tensor_lstm', 'shanghai_t2dm') : 256//10,

    ('imv_full_lstm', 'ohio') : 512//16,
    ('imv_full_lstm', 'arises') : 512//26,
    ('imv_full_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_full_lstm', 'shanghai_t2dm') : 256//10,

    ('tgru', 'ohio') : 32*16,
    ('tgru', 'arises') : 20*26,
    ('tgru', 'shanghai_t1dm') : 25*10,
    ('tgru', 'shanghai_t2dm') : 25*10,

    ('retain', 'ohio') : 512,
    ('retain', 'arises') : 512,
    ('retain', 'shanghai_t1dm') : 256,
    ('retain', 'shanghai_t2dm') : 256,
    
    ('gat_simplev2', 'ohio') : 512,
    ('gat_simplev2', 'arises') : 512,
    ('gat_simplev2', 'shanghai_t1dm') : 256,
    ('gat_simplev2', 'shanghai_t2dm') : 256,

    ('gat_exp_layer_1', 'ohio') : 512,
    ('gat_exp_layer_1', 'arises') : 512,
    ('gat_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gat_exp_layer_1', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp_layer_1', 'ohio') : 512,
    ('gatv2_exp_layer_1', 'arises') : 512,
    ('gatv2_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gatv2_exp_layer_1', 'shanghai_t2dm') : 256,


    ('gat_simplev2_layer_1', 'ohio') : 512,
    ('gat_simplev2_layer_1', 'arises') : 512,
    ('gat_simplev2_layer_1', 'shanghai_t1dm') : 256,
    ('gat_simplev2_layer_1', 'shanghai_t2dm') : 256,

    ('gat_exp', 'ohio') : 512,
    ('gat_exp', 'arises') : 512,
    ('gat_exp', 'shanghai_t1dm') : 256,
    ('gat_exp', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp', 'ohio') : 512,
    ('gatv2_exp', 'arises') : 512,
    ('gatv2_exp', 'shanghai_t1dm') : 256,
    ('gatv2_exp', 'shanghai_t2dm') : 256,

    ('att_t_lstm', 'ohio') : 512,
    ('att_t_lstm', 'arises') : 512,
    ('att_t_lstm', 'shanghai_t1dm') : 256,
    ('att_t_lstm', 'shanghai_t2dm') : 256,
    
    ('att_f_lstm', 'ohio') : 512,
    ('att_f_lstm', 'arises') : 512,
    ('att_f_lstm', 'shanghai_t1dm') : 256,
    ('att_f_lstm', 'shanghai_t2dm') : 256,
    
    ('NHiTS', 'ohio') : 256,
    ('NHiTS', 'arises') : 256,
    ('NHiTS', 'shanghai_t1dm') : 128,
    ('NHiTS', 'shanghai_t2dm') : 128,
    
    
    ('ETN-ODE', 'ohio') : 32*16,
    ('ETN-ODE', 'arises') : 20*26,
    ('ETN-ODE', 'shanghai_t1dm') : 25*10,
    ('ETN-ODE', 'shanghai_t2dm') : 25*10,
    
}

# %%
from gat_mem_org_log.train import *
seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

datasets = ['ohio', 'arises', 'shanghai_t1dm', 'shanghai_t2dm']


# methods = ['gatv2_exp', 'gatv2_exp_layer_1', 'gat_exp', 'gat_exp_layer_1',
#            'MNODE', 'LPSC', 'LP', 'NHiTS', 'NBEATS', 'att_f_lstm','att_t_lstm' , 'ETN-ODE', 'imv_tensor_lstm','imv_full_lstm', 'retain',  'xgboost', 'linear_regression']
methods = ['att_f_lstm','att_t_lstm' , 'ETN-ODE', 'imv_tensor_lstm','imv_full_lstm', 'retain']
for dataset in datasets:
    for method in methods:

        version = 'nips_23'
        CONF = select_conf(dataset=dataset, version=version, seed=seed, method=method, hidden_dim=mthd_dt2hidden_dim[(method, dataset)])
        global_model = get_model(CONF)
        global_model.to(CONF['device'])
        data_proc = DataProcessor(CONF)
        update = Update(data_proc, CONF)
        pid2model = create_pid2model(data_proc, CONF, global_model)
        start_time = time.time()
        for pid in data_proc.test_pid2data_npy.keys():

            output_dict = update.test_inference(pid2model[pid], pid)
        predict_time = time.time() - start_time

        np.save(f'./results/test_time/{dataset}_{method}.npy', [predict_time])
        print(dataset, method, predict_time)
# Out:
# ohio att_f_lstm 2.6118505001068115
# ohio att_t_lstm 2.1050031185150146
# ohio ETN-ODE 28.121161699295044
# ohio imv_tensor_lstm 6.225085496902466
# ohio imv_full_lstm 4.978373765945435
# ohio retain 2.5672085285186768
# arises att_f_lstm 2.520205497741699
# arises att_t_lstm 2.345191240310669
# arises ETN-ODE 27.032840967178345
# arises imv_tensor_lstm 6.41073751449585
# arises imv_full_lstm 5.186737775802612
# arises retain 2.707833766937256
# shanghai_t1dm att_f_lstm 0.17501378059387207
# shanghai_t1dm att_t_lstm 0.15038323402404785
# shanghai_t1dm ETN-ODE 1.0622379779815674
# shanghai_t1dm imv_tensor_lstm 0.2903168201446533
# shanghai_t1dm imv_full_lstm 0.26102137565612793
# shanghai_t1dm retain 0.1660139560699463
# shanghai_t2dm att_f_lstm 1.4064843654632568
# shanghai_t2dm att_t_lstm 1.2343506813049316
# shanghai_t2dm ETN-ODE 7.478271245956421
# shanghai_t2dm imv_tensor_lstm 2.276864767074585
# shanghai_t2dm imv_full_lstm 1.909153699874878
# ...

# %%
from gat_mem_org_log.dataprocessor import *
from util import *
import xgboost as xgb
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import RandomizedSearchCV 
from sklearn.model_selection import GridSearchCV, KFold
from gat_mem_org_log.log import *
def custom_scorer(y_true, y_pred, actual_scorer):
    score = np.nan

    try:
      score = -actual_scorer(y_true, y_pred)
    except Exception: 
      pass

    return score


from sklearn.metrics import make_scorer
rmse = make_scorer(custom_scorer, actual_scorer = mean_squared_error)

def get_variable_importance(pid2feature_importance):
    temp_list = []
    for pid in pid2feature_importance:
        temp_list.append(np.expand_dims(pid2feature_importance[pid], axis=0))
    return np.concatenate(temp_list, axis=0).mean(axis=0)

class XGB():
    def __init__(self, CONF):
        self.CONF = CONF
        self.pid2model = {}
        self.metrics_dic = {
            'rmse': [],
            'mape': [],
            'mae': [],
            'grmse': [],
            'time_lag' : [],
        }
        self.pid2feature_importance = {}
        self.pid2prediction = {}

    def __call__(self, data_proc,  pid, batch_size):
        seed = 1
        random.seed(seed)
        np.random.seed(seed)
        os.environ['PYTHONHASHSEED'] = str(seed)


        
        mean, std = data_proc.get_mean_std(pid)
        # params = {
        #     'min_child_weight': [1, 5, 10],
        #     'gamma': [0.5, 1, 1.5, 2, 5],
        #     'subsample': [0.6, 0.8, 1.0],
        #     'colsample_bytree': [0.6, 0.8, 1.0],
        #     'max_depth': [3, 4, 5, 6, 7]
        #     'n_estimators': [50,100,200],
        #     'learning_rate': [0.01, 0.1, 1],
        # }
        # G, attris, time_attris, y, target_time = data_proc.get_all_train(device='cpu', seq_len=self.CONF['seq_len'], attri_list=self.CONF['attri_list'], time_attri_list=self.CONF['time_attri_list'], pid=pid,)
        # X = torch.cat([torch.unsqueeze(G, dim=2), attris, time_attris], dim=2).detach().cpu().numpy()
        # B, T, N = X.shape
        # X = X.reshape(B, -1)
        # y_norm = (y-mean)/std
        
        # xgb_cv = RandomizedSearchCV(xgb.XGBRegressor(objective="reg:squarederror", random_state=seed), params, cv=3, scoring = rmse, random_state=seed, n_iter=10,)
        # xgb_cv.fit(X, y_norm)
        
        # self.pid2model[pid] = xgb.XGBRegressor(**xgb_cv.best_params_)

        
        if pid not in self.pid2model:
            self.pid2model[pid] = xgb.XGBRegressor(
                # tree_method='gpu_hist', 
                objective="reg:squarederror", random_state=seed, min_child_weight=5, gamma=1, subsample=0.95, colsample_bytree=1.0, max_depth=5, n_estimators=50, learning_rate=0.1)
    
        
        G, attris, time_attris, y, target_time, _ = data_proc.get_all_train(device='cpu', seq_len=self.CONF['seq_len'], attri_list=self.CONF['attri_list'], time_attri_list=self.CONF['time_attri_list'], pid=pid)
        X = torch.cat([torch.unsqueeze(G, dim=2), attris, time_attris], dim=2).detach().cpu().numpy()
        B, T, N = X.shape
        X = X.reshape(B, -1)
        y_norm = (y-mean)/std

        self.pid2model[pid].fit(X, y_norm)
        
        start_time = time.time()
        G, attris, time_attris, y, target_time, seq_st_ed, _  = data_proc.get_test(device='cpu', seq_len=self.CONF['seq_len'], attri_list=self.CONF['attri_list'], time_attri_list=self.CONF['time_attri_list'], pid=pid)
        X = torch.cat([torch.unsqueeze(G, dim=2), attris, time_attris], dim=2).detach().cpu().numpy()
        B, T, N = X.shape
        X = X.reshape(B, -1)
        predict_time = time.time() - start_time

        # self.pid2model[pid] = random_search
        pred = self.pid2model[pid].predict(X)


        predicted_np = pred*std + mean

        self.pid2prediction[pid] = predicted_np
        self.metrics_dic['rmse'].append(mean_squared_error(y, predicted_np)**0.5)
        self.metrics_dic['mape'].append(mean_absolute_percentage_error(y, predicted_np) * 100)
        self.metrics_dic['mae'].append(mean_absolute_error(y, predicted_np))
        self.metrics_dic['grmse'].append(cal_gmse(y, predicted_np[:, None]))
        self.metrics_dic['time_lag'].append(cal_time_lag(y, predicted_np[:, None], seq_st_ed, self.CONF['interval']))
        feature_importances_ = self.pid2model[pid].feature_importances_.reshape(T, N)
        
        self.pid2feature_importance[pid] = np.mean(np.abs(feature_importances_), axis=0)
        # colsample_bytree=1.0, gamma=1, max_depth=5, min_child_weight=5, subsample=1.0;, score=-0.176
        return predict_time

class LR():
    def __init__(self, CONF):
        self.CONF = CONF
        self.pid2model = {}
        self.metrics_dic = {
            'rmse': [],
            'mape': [],
            'mae': [],
            'grmse': [],
            'time_lag' : [],
        }

        self.pid2feature_importance = {

        }
        self.pid2prediction = {}
        self.X1 = None
    def __call__(self, data_proc,  pid, batch_size=None):
        
        seed = 1
        if batch_size is not None: 
            seed = 1
        random.seed(seed)
        np.random.seed(seed)
        os.environ['PYTHONHASHSEED'] = str(seed)



       
        if pid not in self.pid2model:
            self.pid2model[pid] = LinearRegression()
        
        mean, std = data_proc.get_mean_std(pid)

        G, attris, time_attris, y, target_time, _  = data_proc.get_all_train(device='cpu', seq_len=self.CONF['seq_len'], attri_list=self.CONF['attri_list'], time_attri_list=self.CONF['time_attri_list'], pid=pid)
        G_np = G.detach().cpu().numpy()[..., None]
        attri_np = attris.detach().cpu().numpy()
        time_attris_np = time_attris.detach().cpu().numpy()
        X = np.concatenate([G_np, attri_np, time_attris_np], axis=-1)
        B, T, C = X.shape
        X = X.transpose(0, 2, 1) # B C T
        # X = X[:, 0, :]
        y_norm = (y-mean)/std
        X = X.reshape(B, -1)
        self.pid2model[pid].fit(X, y_norm)
        
        start_time = time.time()
        G, attris, time_attris, y, target_time, seq_st_ed, _  = data_proc.get_test(device='cpu', seq_len=self.CONF['seq_len'], attri_list=self.CONF['attri_list'], time_attri_list=self.CONF['time_attri_list'], pid=pid)
        G_np = G.detach().cpu().numpy()[..., None]
        T = G_np.shape[1]
        attri_np = attris.detach().cpu().numpy()
        time_attris_np = time_attris.detach().cpu().numpy()
        X = np.concatenate([G_np, attri_np, time_attris_np], axis=-1)
        B, T, C = X.shape
        X = X.transpose(0, 2, 1) # B C T
        # X = X[:, 0, :]
        X = X.reshape(B, -1)
        pred = self.pid2model[pid].predict(X)
        predicted_np = pred*std + mean
        predicted_np = np.clip(predicted_np, 40, 400)
        predict_time = time.time() - start_time


        self.pid2prediction[pid] = predicted_np
        self.metrics_dic['rmse'].append(mean_squared_error(y, predicted_np)**0.5)
        self.metrics_dic['mape'].append(mean_absolute_percentage_error(y, predicted_np) * 100)
        self.metrics_dic['mae'].append(mean_absolute_error(y, predicted_np))
        self.metrics_dic['grmse'].append(cal_gmse(y, predicted_np[:, None]))
        self.metrics_dic['time_lag'].append(cal_time_lag(y, predicted_np[:, None], seq_st_ed, self.CONF['interval']))

        feature_importances_ = self.pid2model[pid].coef_ # 
        feature_importances_ = feature_importances_.reshape(C, T)
        self.pid2feature_importance[pid] = np.abs(feature_importances_).mean(-1)
        return predict_time

# %%
from gat_mem_org_log.train import *
seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

datasets = ['ohio', 'arises', 'shanghai_t1dm', 'shanghai_t2dm']


methods = ['xgboost', 'linear_regression']
for dataset in datasets:
    for method in methods:

        version = 'nips_23'
        CONF = select_conf(dataset=dataset, version=version, seed=seed, method='att_t_lstm', hidden_dim=mthd_dt2hidden_dim[('att_t_lstm', dataset)])
        global_model = get_model(CONF)
        global_model.to(CONF['device'])
        data_proc = DataProcessor(CONF)
        update = Update(data_proc, CONF)

        if method == 'xgboost':
            model = XGB(CONF)
        elif method == 'linear_regression':
            model = LR(CONF)
            
        
        for pid in data_proc.test_pid2data_npy:
            batch_size = 100 if dataset == 'shanghai_t1dm' and method == 'linear_regression' else None
            
            predict_time = model(data_proc, pid, batch_size) 



        np.save(f'./results/test_time/{dataset}_{method}.npy', [predict_time])
        print(dataset, method, predict_time)
# Out:
# ohio xgboost 0.02800297737121582
# ohio linear_regression 0.01700139045715332
# arises xgboost 0.02700328826904297
# arises linear_regression 0.03200125694274902
# shanghai_t1dm xgboost 0.0020041465759277344
# shanghai_t1dm linear_regression 0.0020008087158203125
# shanghai_t2dm xgboost 0.0020003318786621094
# shanghai_t2dm linear_regression 0.0019996166229248047

# %%
import xlwt
book = xlwt.Workbook(encoding='utf-8', style_compression=0)


method2name = {
    'gatv2_exp_acc': 'GATv2+GRU (L=2)',
    'gatv2_exp_layer_1_acc' :  'GATv2+GRU (L=1)',
    'gat_exp_acc': 'GAT+GRU (L=2)', 
    'gat_exp_layer_1_acc': 'GAT+GRU (L=1)',
    'gat_simplev2': 'Gate+GRU (L=2)',
    'gat_simplev2_layer_1': 'Gate+GRU (L=1)',
    'xgboost': 'XGBoost',
    'linear_regression':'LR',
    'imv_tensor_lstm': 'IMV-TENSOR',
    'imv_full_lstm': 'IMV-FULL',
    'retain': 'RETAIN',
    'tgru' : 'TGRU',
    'att_t_lstm': 'ATT-T-LSTM',
    'att_f_lstm':'ATT-F-LSTM',
    'NHiTS':'NHiTS',
    'NBEATS':'N-BEATS',
    'ETN-ODE': 'ETN-ODE',
    'LP':'LP',
    'MNODE':'MNODE',
    'LPSC':'LPSC',
}

dataset2name = {
    'ohio' : 'OhioT1DM',
    'arises': 'ArisesT1DM',
    'shanghai_t1dm': 'ShanghaiT1DM',
    'shanghai_t2dm' : 'ShanghaiT2DM'
}
methods = ['gatv2_exp_acc', 'gatv2_exp_layer_1_acc', 'gat_exp_acc', 'gat_exp_layer_1_acc',
           'MNODE', 'LPSC', 'LP', 'NHiTS', 'NBEATS', 'att_f_lstm','att_t_lstm' , 'ETN-ODE', 'imv_tensor_lstm','imv_full_lstm', 'retain',  'xgboost', 'linear_regression'][::-1]
    
sheet = book.add_sheet('time_consumption', cell_overwrite_ok=True)
sheet.write(0, 0, 'Method')
for j, dataset in enumerate(datasets):
    sheet.write(0, j + 1, dataset2name[dataset])

for i, method in enumerate(methods):
    sheet.write(i+1, 0, method2name[method])
    
for i, method in enumerate(methods):
    for j, dataset in enumerate(datasets):

        time = np.load(f'./results/test_time/{dataset}_{method}.npy')[0]
        sheet.write(i + 1 , j + 1, f'{time:.2f}' )
if not os.path.exists('./results'):
    os.makedirs('./results')
book.save(f'./results/time_consumption.xls')
