# %%
def select_conf(version, dataset, seed, method, hidden_dim):
    if dataset == 'ohio':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [ 'meal', 'bolus', 'basal', 'finger_stick',
            'basis_skin_temperature', 'basis_gsr', 'basis_sleep', 'acceleration',
            'exercise', 'sleep', 'work', 'basis_steps', 'basis_heart_rate', 'basis_air_temperature'],
            
            'time_attri_list' : ['timestamp'],     

            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,

            
            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'arises':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [
            'meal', 'bolus', 'basal', 'correction_bolus',
            'finger_stick', 'EDA', 'SCL', 'SCR', 'HR', 'TEMP', 'ACC', 'RMSSD', 'SDNN',
            'medianNNI', 'CVNNI', 'CVSD', 'pNNX', 'meanHR', 'minHR', 'maxHR', 'VLF',
            'LF', 'HF', 'LHR', ],
            'time_attri_list' : ['timestamp'],     
            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,


            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'shanghai_t2dm':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],  

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,


            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,

        }
    elif dataset == 'shanghai_t1dm':

        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,


            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],    

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,

            'epochs': 20,
            'local_epochs': 500,
            'tuning_epochs': 0, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,

            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,
        }
    return CONF

# %%
mthd_dt2hidden_dim = {
    ('imv_tensor_lstm', 'ohio') : 512//16,
    ('imv_tensor_lstm', 'arises') : 512//26,
    ('imv_tensor_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_tensor_lstm', 'shanghai_t2dm') : 256//10,

    ('imv_full_lstm', 'ohio') : 512//16,
    ('imv_full_lstm', 'arises') : 512//26,
    ('imv_full_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_full_lstm', 'shanghai_t2dm') : 256//10,

    ('tgru', 'ohio') : 32*16,
    ('tgru', 'arises') : 20*26,
    ('tgru', 'shanghai_t1dm') : 25*10,
    ('tgru', 'shanghai_t2dm') : 25*10,

    ('retain', 'ohio') : 512,
    ('retain', 'arises') : 512,
    ('retain', 'shanghai_t1dm') : 256,
    ('retain', 'shanghai_t2dm') : 256,
    
    ('gat_simplev2', 'ohio') : 512,
    ('gat_simplev2', 'arises') : 512,
    ('gat_simplev2', 'shanghai_t1dm') : 256,
    ('gat_simplev2', 'shanghai_t2dm') : 256,

    ('gat_exp_layer_1', 'ohio') : 512,
    ('gat_exp_layer_1', 'arises') : 512,
    ('gat_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gat_exp_layer_1', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp_layer_1', 'ohio') : 512,
    ('gatv2_exp_layer_1', 'arises') : 512,
    ('gatv2_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gatv2_exp_layer_1', 'shanghai_t2dm') : 256,


    ('gat_simplev2_layer_1', 'ohio') : 512,
    ('gat_simplev2_layer_1', 'arises') : 512,
    ('gat_simplev2_layer_1', 'shanghai_t1dm') : 256,
    ('gat_simplev2_layer_1', 'shanghai_t2dm') : 256,

    ('gat_exp', 'ohio') : 512,
    ('gat_exp', 'arises') : 512,
    ('gat_exp', 'shanghai_t1dm') : 256,
    ('gat_exp', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp', 'ohio') : 512,
    ('gatv2_exp', 'arises') : 512,
    ('gatv2_exp', 'shanghai_t1dm') : 256,
    ('gatv2_exp', 'shanghai_t2dm') : 256,

    ('att_t_lstm', 'ohio') : 512,
    ('att_t_lstm', 'arises') : 512,
    ('att_t_lstm', 'shanghai_t1dm') : 256,
    ('att_t_lstm', 'shanghai_t2dm') : 256,
    
    ('att_f_lstm', 'ohio') : 512,
    ('att_f_lstm', 'arises') : 512,
    ('att_f_lstm', 'shanghai_t1dm') : 256,
    ('att_f_lstm', 'shanghai_t2dm') : 256,
    
    ('NHiTS', 'ohio') : 512,
    ('NHiTS', 'arises') : 512,
    ('NHiTS', 'shanghai_t1dm') : 256,
    ('NHiTS', 'shanghai_t2dm') : 256,
}

# %%
for method in ['NHiTS']:
    print(f'############################### {method} #############################')
    for dataset in ['shanghai_t1dm', 'ohio', 'arises', 'shanghai_t2dm', ]:
        for seed in [1, 10, 20, 100]:
            
            print(f'----------------{seed=}--{dataset=}------------------------')
            from gat_mem_org_log.train import *
            random.seed(seed)
            np.random.seed(seed)
            torch.manual_seed(seed)
            torch.cuda.manual_seed(seed)
            torch.backends.cudnn.deterministic = True
            torch.backends.cudnn.benchmark = False
            os.environ['PYTHONHASHSEED'] = str(seed)

            version = 'nips_23'

            CONF = select_conf(dataset=dataset, version=version, seed=seed, method=method, hidden_dim=mthd_dt2hidden_dim[(method, dataset)])
            pid2model = train(CONF)
            print('end')
# Out:
# ############################### NHiTS #############################
# ----------------seed=1--dataset='shanghai_t1dm'------------------------
# global_loop: 100%|██████████| 20/20 [00:47<00:00,  2.35s/it]
#
#  Results after 20 global rounds of training:
# rmse, 15.24201, 3.35159
# mape, 10.26825, 4.01386
# mae, 11.83720, 2.96680
# grmse, 18.83482, 5.28374
# time_lag, -3.75000, 6.49519
# [11.743244582948996, 11.058747598055577, 12.31785939334346, 14.784637127610443, 22.42401925178216, 16.636289047778956, 12.476651778406312, 13.011249076820507, 17.783793342930593, 17.18426816206105, 13.96519175702743, 19.51812918656292]
# tune_loop: 0it [00:00, ?it/s]
#
#  Results after 0 of fine tuning:
# rmse, 15.24201, 3.35159
# mape, 10.26825, 4.01386
# mae, 11.83720, 2.96680
# grmse, 18.83482, 5.28374
# time_lag, -3.75000, 6.49519
# [11.743244582948996, 11.058747598055577, 12.31785939334346, 14.784637127610443, 22.42401925178216, 16.636289047778956, 12.476651778406312, 13.011249076820507, 17.783793342930593, 17.18426816206105, 13.96519175702743, 19.51812918656292]
# models have been saved...
# end
# ----------------seed=10--dataset='shanghai_t1dm'------------------------
# global_loop: 100%|██████████| 20/20 [00:47<00:00,  2.38s/it]
#
#  Results after 20 global rounds of training:
# rmse, 14.64597, 3.02267
# mape, 8.86941, 2.51652
# mae, 11.05365, 2.32010
# grmse, 17.18881, 4.09599
# time_lag, -3.75000, 6.49519
# [12.478662819262164, 11.609513663160795, 12.6776957096256, 14.798956880667616, 20.313952021419063, 17.292270340397486, 13.02999469373453, 11.856605819647543, 13.137399393235436, 13.59629555907371, 14.09927158503288, 20.860993763265824]
# tune_loop: 0it [00:00, ?it/s]
#
#  Results after 0 of fine tuning:
# rmse,
/it]
#
#  Results after 30 of fine tuning:
# rmse, 20.18055, 2.51599
# mape, 9.64345, 1.74680
# mae, 14.09816, 1.60682
# grmse, 25.34254, 3.32391
# time_lag, -7.21528, 4.46598
# [19.31172647748035, 18.869868307215093, 17.476902132652025, 24.787320445800763, 18.673597593134335, 21.53765906631082, 22.930210545567665, 17.964203738735453, 17.720931199795643, 21.832070039887707, 23.641448577029127, 17.420654911032962]
# models have been saved...
# end
# ----------------seed=20--dataset='ohio'------------------------
# global_loop: 100%|██████████| 30/30 [02:06<00:00,  4.23s/it]
#
#  Results after 30 global rounds of training:
# rmse, 21.16439, 2.68202
# mape, 10.20021, 1.78661
# mae, 15.07394, 1.64364
# grmse, 25.15413, 3.41769
# time_lag, -9.25000, 5.21427
# [20.268248071375396, 19.335265928994147, 18.009846854991142, 25.672508598769742, 19.562958635797845, 22.602542079316336, 24.2671605377804, 19.2264442486713, 18.31926386257911, 23.709434157448936, 24.588472025381503, 18.410551180651563]
# tune_loop: 100%|██████████| 30/30 [04:11<00:00,  8.39s/it]
#
#  Results after 30 of fine tuning:
# rmse, 20.10540, 2.46659
# mape, 9.58234, 1.72690
# mae, 14.05969, 1.58843
# grmse, 25.18683, 3.19518
# time_lag, -7.85417, 4.57931
# [19.164665228240928, 18.768856891501727, 17.35733473468196, 24.3570784978252, 18.68679859286739, 21.287386688629724, 22.680688597436944, 18.06083993642002, 17.79287313023154, 22.25350821622711, 23.614658574905864, 17.24005901990378]
# models have been saved...
# end
# ----------------seed=100--dataset='ohio'------------------------
# global_loop: 100%|██████████| 30/30 [02:03<00:00,  4.13s/it]
#
#  Results after 30 global rounds of training:
# rmse, 20.36765, 2.67502
# mape, 9.73353, 1.74164
# mae, 14.27164, 1.68072
# grmse, 25.29398, 3.43285
# time_lag, -8.70139, 5.22054
# [19.632990479943366, 18.505686942633336, 17.23143089512184, 25.33748164427986, 18.605312515746512, 21.803761652907436, 23.31560096877531, 18.570499841293145, 17.86644107809037, 22.547604533848908, 23.59562673620302, 17.39940921175109]
# tune_loop: 100%|██████████| 30/30 [03:50<00:00,  7.68s/it]
#
#  Results after 30 of fine tuning:
# rmse, 20.15943, 2.51877
# mape, 9.58815, 1.73947
# mae, 14.07787, 1.64829
# grmse, 25.26751, 3.22752
# time_lag, -7.63194, 4.80974
# [19.34260222892277, 18.657067055757903, 17.186927369722298, 24.667425332989126, 18.641649011846013, 21.601590754954398, 22.99901280150411, 18.18959311275054, 17.85925624003602, 21.91055912838281, 23.528648283296313, 17.328850582193848]
# models have been saved...
# end
# ----------------seed=1--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 [02:04<00:00,  4.14s/it]
#
#  Results after 30 global rounds of training:
# rmse, 22.34552, 4.96568
# mape, 10.92828, 2.64695
# mae, 16.02039, 3.30367
# grmse, 27.97682, 6.85819
# time_lag, -11.84028, 6.52066
# [25.15501015966427, 21.52454695983569, 26.672705665887413, 14.828430622838281, 22.009368288991595, 24.81619319767274, 32.25188115274247, 19.288283291015123, 24.565039428207214, 17.679330185850155, 25.03794483660001, 14.317535980323274]
# tune_loop: 100%|██████████| 30/30 [03:47<00:00,  7.60s/it]
#
#  Results after 30 of fine tuning:
# rmse, 21.90561, 4.50999
# mape, 10.58310, 2.60232
# mae, 15.70142, 3.05056
# grmse, 27.64724, 6.11492
# time_lag, -11.84028, 6.52066
# [24.874035687181674, 21.442792856307587, 24.461913107340845, 14.76435954812165, 21.74376861053925, 24.328580348580633, 30.786654823711768, 19.639345405065136, 24.40288369070088, 17.628486018008164, 24.42228736456083, 14.372163442963275]
# models have been saved...
# end
# ----------------seed=10--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 