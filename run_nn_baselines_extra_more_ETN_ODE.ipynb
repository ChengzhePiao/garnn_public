# %%
def select_conf(version, dataset, seed, method, hidden_dim):
    if dataset == 'ohio':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [ 'meal', 'bolus', 'basal', 'finger_stick',
            'basis_skin_temperature', 'basis_gsr', 'basis_sleep', 'acceleration',
            'exercise', 'sleep', 'work', 'basis_steps', 'basis_heart_rate', 'basis_air_temperature'],
            
            'time_attri_list' : ['timestamp'],     

            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,

            
            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'arises':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [
            'meal', 'bolus', 'basal', 'correction_bolus',
            'finger_stick', 'EDA', 'SCL', 'SCR', 'HR', 'TEMP', 'ACC', 'RMSSD', 'SDNN',
            'medianNNI', 'CVNNI', 'CVSD', 'pNNX', 'meanHR', 'minHR', 'maxHR', 'VLF',
            'LF', 'HF', 'LHR', ],
            'time_attri_list' : ['timestamp'],     
            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,


            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'shanghai_t2dm':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],  

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,


            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,

        }
    elif dataset == 'shanghai_t1dm':

        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,


            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],    

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,

            'epochs': 20,
            'local_epochs': 500,
            'tuning_epochs': 0, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,

            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,
        }
    return CONF

# %%
mthd_dt2hidden_dim = {
    ('imv_tensor_lstm', 'ohio') : 512//16,
    ('imv_tensor_lstm', 'arises') : 512//26,
    ('imv_tensor_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_tensor_lstm', 'shanghai_t2dm') : 256//10,

    ('imv_full_lstm', 'ohio') : 512//16,
    ('imv_full_lstm', 'arises') : 512//26,
    ('imv_full_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_full_lstm', 'shanghai_t2dm') : 256//10,

    ('tgru', 'ohio') : 32*16,
    ('tgru', 'arises') : 20*26,
    ('tgru', 'shanghai_t1dm') : 25*10,
    ('tgru', 'shanghai_t2dm') : 25*10,

    ('retain', 'ohio') : 512,
    ('retain', 'arises') : 512,
    ('retain', 'shanghai_t1dm') : 256,
    ('retain', 'shanghai_t2dm') : 256,
    
    ('gat_simplev2', 'ohio') : 512,
    ('gat_simplev2', 'arises') : 512,
    ('gat_simplev2', 'shanghai_t1dm') : 256,
    ('gat_simplev2', 'shanghai_t2dm') : 256,

    ('gat_exp_layer_1', 'ohio') : 512,
    ('gat_exp_layer_1', 'arises') : 512,
    ('gat_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gat_exp_layer_1', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp_layer_1', 'ohio') : 512,
    ('gatv2_exp_layer_1', 'arises') : 512,
    ('gatv2_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gatv2_exp_layer_1', 'shanghai_t2dm') : 256,


    ('gat_simplev2_layer_1', 'ohio') : 512,
    ('gat_simplev2_layer_1', 'arises') : 512,
    ('gat_simplev2_layer_1', 'shanghai_t1dm') : 256,
    ('gat_simplev2_layer_1', 'shanghai_t2dm') : 256,

    ('gat_exp', 'ohio') : 512,
    ('gat_exp', 'arises') : 512,
    ('gat_exp', 'shanghai_t1dm') : 256,
    ('gat_exp', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp', 'ohio') : 512,
    ('gatv2_exp', 'arises') : 512,
    ('gatv2_exp', 'shanghai_t1dm') : 256,
    ('gatv2_exp', 'shanghai_t2dm') : 256,

    ('att_t_lstm', 'ohio') : 512,
    ('att_t_lstm', 'arises') : 512,
    ('att_t_lstm', 'shanghai_t1dm') : 256,
    ('att_t_lstm', 'shanghai_t2dm') : 256,
    
    ('att_f_lstm', 'ohio') : 512,
    ('att_f_lstm', 'arises') : 512,
    ('att_f_lstm', 'shanghai_t1dm') : 256,
    ('att_f_lstm', 'shanghai_t2dm') : 256,
    
    ('NHiTS', 'ohio') : 512,
    ('NHiTS', 'arises') : 512,
    ('NHiTS', 'shanghai_t1dm') : 256,
    ('NHiTS', 'shanghai_t2dm') : 256,
    
    ('NBEATS', 'ohio') : 512,
    ('NBEATS', 'arises') : 512,
    ('NBEATS', 'shanghai_t1dm') : 256,
    ('NBEATS', 'shanghai_t2dm') : 256,

    ('ETN-ODE', 'ohio') : 32*16,
    ('ETN-ODE', 'arises') : 20*26,
    ('ETN-ODE', 'shanghai_t1dm') : 25*10,
    ('ETN-ODE', 'shanghai_t2dm') : 25*10,
    
}

# %%
for method in ['ETN-ODE']:
    print(f'############################### {method} #############################')
    for dataset in ['shanghai_t1dm', 'ohio', 'arises', 'shanghai_t2dm', ]:
        for seed in [1, 10, 20, 100]:
            
            print(f'----------------{seed=}--{dataset=}------------------------')
            from gat_mem_org_log.train import *
            random.seed(seed)
            np.random.seed(seed)
            torch.manual_seed(seed)
            torch.cuda.manual_seed(seed)
            torch.backends.cudnn.deterministic = True
            torch.backends.cudnn.benchmark = False
            os.environ['PYTHONHASHSEED'] = str(seed)

            version = 'nips_23'

            CONF = select_conf(dataset=dataset, version=version, seed=seed, method=method, hidden_dim=mthd_dt2hidden_dim[(method, dataset)])
            pid2model = train(CONF)
            print('end')
# Out:
# ############################### ETN-ODE #############################
# ----------------seed=1--dataset='shanghai_t1dm'------------------------
# global_loop: 100%|██████████| 20/20 
#  Results after 0 of fine tuning:
# rmse, 15.58050, 3.42428
# mape, 10.37125, 4.30938
# mae, 12.05703, 3.09352
# grmse, 19.49934, 5.34654
# time_lag, -3.75000, 6.49519
# [12.082884962159868, 11.212096044776157, 12.194571140782983, 14.81861358541176, 21.570741178735606, 17.842751176072877, 12.22054064964113, 14.376383573871626, 19.685202618932767, 15.077506666401797, 15.172102795824655, 20.712622379362738]
# models have been saved...
# end
# ----------------seed=1--dataset='ohio'------------------------
# global_loop: 100%|██████████| 30/30 [1:18:10<00:00, 156.36s/it]
#
#  Results after 30 global rounds of training:
# rmse, 21.62593, 3.11931
# mape, 11.23897, 2.19097
# mae, 15.68333, 2.11544
# grmse, 26.70787, 4.06041
# time_lag, -9.03472, 6.12292
# [20.45762832991072, 18.32545653395119, 19.035151841139445, 26.98563483234529, 18.317908624272246, 22.807464127383277, 25.616131992588553, 20.613523677392894, 19.084412834363594, 24.224142544809506, 25.645086687149377, 18.398617468599628]
# tune_loop: 100%|██████████| 30/30 [4:12:42<00:00, 505.40s/it]
#
#  Results after 30 of fine tuning:
# rmse, 21.21285, 3.09057
# mape, 10.29675, 2.02542
# mae, 14.96336, 2.06309
# grmse, 26.73392, 4.11934
# time_lag, -9.17361, 5.97123
# [20.034082745050917, 18.436943019923934, 18.48552653191435, 27.041417885347656, 18.52582953239291, 21.758461194324425, 25.805255159514626, 19.478479492251907, 18.83230876104904, 23.420432587756707, 24.677551892009316, 18.057946076558824]
# models have been saved...
# end
# ----------------seed=10--dataset='ohio'------------------------
# global_loop: 100%|██████████| 30/30 [2:35:31<00:00, 311.06s/it]
#
#  Results after 30 global rounds of training:
# rmse, 20.94429, 2.78681
# mape, 9.92799, 1.81895
# mae, 14.65901, 1.77697
# grmse, 26.13077, 3.65731
# time_lag, -9.09722, 5.48724
# [19.987193012563928, 18.794861696002847, 18.60896255971375, 26.494422181626856, 18.44596766625517, 21.74381983856275, 24.471336569067137, 18.67765012676414, 18.44753021002024, 23.226687320973046, 23.987036700841145, 18.445956912451454]
# tune_loop: 100%|██████████| 30/30 [2:30:24<00:00, 300.80s/it]
#
#  Results after 30 of fine tuning:
# c:\code\fornips23\gat_mem_org_log\log.py:136: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize = (20, 15))
# rmse, 20.72882, 2.75128
# mape, 9.97854, 1.90644
# mae, 14.57596, 1.83030
# grmse, 26.12398, 3.73684
# time_lag, -8.56250, 5.07115
# [19.93199038537437, 18.762172969074886, 18.143209636340618, 26.282879101930952, 18.531476435958478, 21.542847985268946, 23.904410417375782, 18.169879780835096, 18.35215200335636, 22.596717987760066, 24.176516855931837, 18.351536724385902]
# models have been saved...
# end
# ----------------seed=20--dataset='ohio'------------------------
# global_loop: 100%|██████████| 30/30 [1:16:34<00:00, 153.14s/it]
#
#  Results after 30 global rounds of training:
# rmse, 21.45247, 2.83230
# mape, 10.05261, 1.74896
# mae, 15.04284, 1.70514
# grmse, 25.99249, 3.73519
# time_lag, -8.88889, 5.10337
# [20.899837861960794, 19.38930214942758, 18.860394416317558, 26.8931965105431, 18.88283431809869, 22.454489563615113, 24.91566708536205, 19.174763879229875, 18.789920068787048, 23.82019975785061, 24.657628783533962, 18.69138869839824]
# tune_loop: 100%|██████████| 30/30 [2:18:59<00:00, 277.97s/it]
#
#  Results after 30 of fine tuning:
# rmse, 20.82002, 2.83527
# mape, 9.99219, 1.88710
# mae, 14.63031, 1.83466
# grmse, 26.05921, 3.88424
# time_lag, -8.20139, 4.97045
# [20.164688307559224, 18.860820774895625, 17.984011861016647, 26.231588828002895, 18.43765972520857, 21.620639603970222, 24.4431414324333, 18.28162392779974, 18.345905131865855, 22.69493733553945, 24.445467301363482, 18.329784997822703]
# models have been saved...
# end
# ----------------seed=100--dataset='ohio'------------------------
# global_loop: 100%|██████████| 30/30 [1:18:49<00:00, 157.64s/it]
#
#  Results after 30 global rounds of training:
# rmse, 21.40848, 2.99474
# mape, 10.07578, 1.80985
# mae, 14.98309, 1.87253
# grmse, 26.34345, 3.87729
# time_lag, -9.09722, 5.40221
# [20.592998670380215, 18.94270358969673, 18.403477613789466, 26.75411927066968, 18.94419374918449, 22.51056880684743, 25.665213539636802, 19.042388212304804, 18.801793698715624, 24.087968461648547, 24.597510780993545, 18.558821085615612]
# tune_loop: 100%|██████████| 30/30 [2:58:25<00:00, 356.85s/it]
#
#  Results after 30 of fine tuning:
# rmse, 21.22137, 3.00497
# mape, 10.16336, 1.96332
# mae, 14.93789, 1.97872
# grmse, 26.72730, 4.01534
# time_lag, -8.61111, 4.84748
# [20.670815738403157, 18.804283400830514, 18.08230170663474, 26.719484410593868, 18.892179843218614, 21.991345177030723, 25.5239061978698, 18.661193499405808, 18.798057715544793, 23.13362645266761, 24.935962906889117, 18.443279847500094]
# models have been saved...
# end
# ----------------seed=1--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 [1:30:33<00:00, 181.13s/it]
#
#  Results after 30 global rounds of training:
# rmse, 23.60276, 5.51752
# mape, 12.01922, 2.91924
# mae, 17.17992, 3.63854
# grmse, 29.74901, 7.30456
# time_lag, -12.11806, 7.01243
# [28.58407238893607, 22.048427340591875, 28.976983769517943, 15.817434151736851, 21.338736485665862, 26.34651388600231, 33.96873562557194, 20.185287496065744, 24.967444623261407, 18.906968284392693, 27.36373376900985, 14.72872632064023]
# tune_loop: 100%|██████████| 30/30 [2:51:52<00:00, 343.76s/it]
#
#  Results after 30 of fine tuning:
# rmse, 23.20832, 5.37395
# mape, 10.98067, 2.76568
# mae, 16.37644, 3.33542
# grmse, 29.76892, 7.43109
# time_lag, -11.70139, 6.67200
# [28.248948879435652, 22.01171008484745, 27.269609307741742, 15.66848587403904, 21.165202332954955, 25.307730067548036, 33.95206078635913, 20.091798298975597, 24.44822235198042, 18.320002662625182, 27.23426070328856, 14.781831693595128]
# models have been saved...
# end
# ----------------seed=10--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 [1:14:56<00:00, 149.88s/it]
#
#  Results after 30 global rounds of training:
# rmse, 23.58934, 5.36678
# mape, 11.92555, 2.96658
# mae, 17.14502, 3.60859
# grmse, 29.88499, 7.15639
# time_lag, -12.46528, 6.74961
# [27.7431324201932, 22.18410859314085, 28.565378256920344, 15.768640054084354, 22.06724605356708, 26.578548690405977, 34.02703321269447, 20.294456378942424, 24.955030355402545, 18.92019194749562, 26.991683244204477, 14.976621083446975]
# tune_loop: 100%|██████████| 30/30 [2:12:56<00:00, 265.89s/it]
#
#  Results after 30 of fine tuning:
# rmse, 23.25451, 5.28282
# mape, 11.05795, 2.74755
# mae, 16.48331, 3.37350
# grmse, 29.92361, 7.31167
# time_lag, -12.46528, 6.74961
# [27.900295942370846, 22.03952152459765, 26.794514063268974, 15.504833821301403, 21.70123858454894, 25.47396658616032, 34.00040211159274, 20.390049530912055, 24.710608992441763, 18.41035806766635, 27.1077719266657, 15.020526320255891]
# models have been saved...
# end
# ----------------seed=20--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 [1:22:53<00:00, 165.78s/it]
#
#  Results after 30 global rounds of training:
# rmse, 24.18818, 5.27494
# mape, 11.65278, 2.78708
# mae, 17.24798, 3.33882
# grmse, 31.28032, 7.17862
# time_lag, -13.61111, 7.56403
# [29.010240522542748, 22.98045779417128, 27.375843888605175, 16.636186321164477, 22.882860511216276, 27.009071239108145, 34.672829104718296, 20.90387341686045, 25.52337771648952, 19.16560949091375, 28.191302057882144, 15.906510446510918]
# tune_loop: 100%|██████████| 30/30 [3:32:00<00:00, 424.01s/it]
#
#  Results after 30 of fine tuning:
# rmse, 23.49693, 5.39584
# mape, 11.15300, 2.84878
# mae, 16.64482, 3.43563
# grmse, 30.13041, 7.37594
# time_lag, -13.15972, 7.10263
# [28.744997866476698, 22.303013427763172, 26.98678378435336, 15.202706969297802, 21.780045025851646, 25.410403354390354, 34.29707787525418, 20.56586574847689, 25.444504132078183, 18.524628612589645, 27.26231511965911, 15.4407935702509]
# models have been saved...
# end
# ----------------seed=100--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 [2:05:53<00:00, 251.77s/it]
#
#  Results after 30 global rounds of training:
# rmse, 22.99156, 5.36227
# mape, 10.95850, 2.63509
# mae, 16.23019, 3.29743
# grmse, 29.22150, 7.35918
# time_lag, -12.25694, 6.78382
# [27.552361593782322, 21.76814653040402, 27.74031846527158, 15.37176827061952, 21.238643708397802, 25.78128551133918, 33.45782822496478, 19.80678382026558, 24.27040861574028, 17.904467216006807, 26.490883464661596, 14.515861517516042]
# tune_loop: 100%|██████████| 30/30 [4:29:32<00:00, 539.09s/it]
#
#  Results after 30 of fine tuning:
# rmse, 22.76508, 5.28637
# mape, 10.75469, 2.72431
# mae, 16.03008, 3.27047
# grmse, 29.18631, 7.28415
# time_lag, -11.49306, 6.44478
# [27.4815734164077, 21.541534049574658, 26.85244897794764, 15.05551960758236, 21.1551140123837, 24.637054126562216, 33.37205006567528, 19.966361940294966, 24.179701383275496, 17.832419303691136, 26.591463988115624, 14.515695430063259]
# models have been saved...
# end
# ----------------seed=1--dataset='shanghai_t2dm'------------------------
# global_loop: 100%|██████████| 30/30 [38:56<00:00, 77.87s/it]
#
#  Results after 30 global rounds of training:
# rmse, 14.66454, 4.38243
# mape, 9.51253, 4.29417
# mae, 11.27048, 3.71063
# grmse, 16.69684, 4.98426
# time_lag, -1.35000, 4.29273
# [13.1635443610938, 9.875897716809881, 14.26484148228253, 20.003207903134328, 18.903194968821985, 18.131561985638815, 13.186693501331062, 13.567492150788912, 14.313187628473631, 13.31989151185907, 20.344122770442283, 21.70435111727312, 20.39329035501398, 15.181824930736722, 10.243632874392366, 16.504330153579676, 11.931309877608067, 16.03700459429447, 12.532796940248724, 18.87779447572142, 19.292943045766435, 25.480851706937457, 14.952393835800956, 21.752987711237147, 6.957879453311649, 14.175629477005101, 17.1883549148176, 13.20921353236273, 8.440138566746336, 13.588100478336735, 11.271593859122143, 18.731035330977104, 17.078058