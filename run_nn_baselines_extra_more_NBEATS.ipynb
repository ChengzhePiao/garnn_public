# %%
def select_conf(version, dataset, seed, method, hidden_dim):
    if dataset == 'ohio':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [ 'meal', 'bolus', 'basal', 'finger_stick',
            'basis_skin_temperature', 'basis_gsr', 'basis_sleep', 'acceleration',
            'exercise', 'sleep', 'work', 'basis_steps', 'basis_heart_rate', 'basis_air_temperature'],
            
            'time_attri_list' : ['timestamp'],     

            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,

            
            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'arises':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 48,
            'pred_window' : 6,
            'seq_len': 48,
            'mix_test_and_valid_2018': False,

            'attri_list': [
            'meal', 'bolus', 'basal', 'correction_bolus',
            'finger_stick', 'EDA', 'SCL', 'SCR', 'HR', 'TEMP', 'ACC', 'RMSSD', 'SDNN',
            'medianNNI', 'CVNNI', 'CVSD', 'pNNX', 'meanHR', 'minHR', 'maxHR', 'VLF',
            'LF', 'HF', 'LHR', ],
            'time_attri_list' : ['timestamp'],     
            'model_name': method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 30, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_6_all_features_seed_{seed}',
            'save_model': True,
            'all_edges': True,


            'interval': 5,
            'log_epoch_vari_imp': False,

            'rewrite':False,
        }
    elif dataset == 'shanghai_t2dm':
        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,

            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],  

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,


            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,
            'epochs': 30,
            'local_epochs': 500,
            'tuning_epochs': 10, 
            'tuning_local_epochs': 80,
            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,
            'all_edges':True,


            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,

        }
    elif dataset == 'shanghai_t1dm':

        CONF = {
            'data_path':f'../../code_data/{dataset}/{version}/',
            'log_path': f'../../code_log/{version}/{dataset}',
            'dataset': dataset,
            'n_prev' : 16,
            'pred_window' : 2,
            'seq_len': 16,


            'attri_list': ['finger_stick', 'blood_ketone', 'meal','insulin_dose_sc', 'hypo_agents', 'insulin_bolus', 'basal','insulin_iv'], 
            'time_attri_list' : ['timestamp'],    

            'model_name':method, 

            'hidden_dim': hidden_dim,
            'nhead': 1,
            'num_layers': 2,
            'all_edges':True,

            'lr': 1e-3,  # 1e-4
            'tuning_lr':1e-5,

            'epochs': 20,
            'local_epochs': 500,
            'tuning_epochs': 0, 
            'tuning_local_epochs': 80,


            'weight_decay': 1e-4,
            'batch_size': 128,
            'device': 'cuda',


            'print_every':2,
            'comments': f'pred_2_all_features_seed_{seed}',
            'save_model': True,

            'interval': 15,
            'log_epoch_vari_imp': False,
            'rewrite':False,
        }
    return CONF

# %%
mthd_dt2hidden_dim = {
    ('imv_tensor_lstm', 'ohio') : 512//16,
    ('imv_tensor_lstm', 'arises') : 512//26,
    ('imv_tensor_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_tensor_lstm', 'shanghai_t2dm') : 256//10,

    ('imv_full_lstm', 'ohio') : 512//16,
    ('imv_full_lstm', 'arises') : 512//26,
    ('imv_full_lstm', 'shanghai_t1dm') : 256//10,
    ('imv_full_lstm', 'shanghai_t2dm') : 256//10,

    ('tgru', 'ohio') : 32*16,
    ('tgru', 'arises') : 20*26,
    ('tgru', 'shanghai_t1dm') : 25*10,
    ('tgru', 'shanghai_t2dm') : 25*10,

    ('retain', 'ohio') : 512,
    ('retain', 'arises') : 512,
    ('retain', 'shanghai_t1dm') : 256,
    ('retain', 'shanghai_t2dm') : 256,
    
    ('gat_simplev2', 'ohio') : 512,
    ('gat_simplev2', 'arises') : 512,
    ('gat_simplev2', 'shanghai_t1dm') : 256,
    ('gat_simplev2', 'shanghai_t2dm') : 256,

    ('gat_exp_layer_1', 'ohio') : 512,
    ('gat_exp_layer_1', 'arises') : 512,
    ('gat_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gat_exp_layer_1', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp_layer_1', 'ohio') : 512,
    ('gatv2_exp_layer_1', 'arises') : 512,
    ('gatv2_exp_layer_1', 'shanghai_t1dm') : 256,
    ('gatv2_exp_layer_1', 'shanghai_t2dm') : 256,


    ('gat_simplev2_layer_1', 'ohio') : 512,
    ('gat_simplev2_layer_1', 'arises') : 512,
    ('gat_simplev2_layer_1', 'shanghai_t1dm') : 256,
    ('gat_simplev2_layer_1', 'shanghai_t2dm') : 256,

    ('gat_exp', 'ohio') : 512,
    ('gat_exp', 'arises') : 512,
    ('gat_exp', 'shanghai_t1dm') : 256,
    ('gat_exp', 'shanghai_t2dm') : 256,
    
    ('gatv2_exp', 'ohio') : 512,
    ('gatv2_exp', 'arises') : 512,
    ('gatv2_exp', 'shanghai_t1dm') : 256,
    ('gatv2_exp', 'shanghai_t2dm') : 256,

    ('att_t_lstm', 'ohio') : 512,
    ('att_t_lstm', 'arises') : 512,
    ('att_t_lstm', 'shanghai_t1dm') : 256,
    ('att_t_lstm', 'shanghai_t2dm') : 256,
    
    ('att_f_lstm', 'ohio') : 512,
    ('att_f_lstm', 'arises') : 512,
    ('att_f_lstm', 'shanghai_t1dm') : 256,
    ('att_f_lstm', 'shanghai_t2dm') : 256,
    
    ('NHiTS', 'ohio') : 512,
    ('NHiTS', 'arises') : 512,
    ('NHiTS', 'shanghai_t1dm') : 256,
    ('NHiTS', 'shanghai_t2dm') : 256,
    
    ('NBEATS', 'ohio') : 512,
    ('NBEATS', 'arises') : 512,
    ('NBEATS', 'shanghai_t1dm') : 256,
    ('NBEATS', 'shanghai_t2dm') : 256,
}

# %%
for method in ['NBEATS']:
    print(f'############################### {method} #############################')
    for dataset in ['shanghai_t1dm', 'ohio', 'arises', 'shanghai_t2dm', ]:
        for seed in [1, 10, 20, 100]:
            
            print(f'----------------{seed=}--{dataset=}------------------------')
            from gat_mem_org_log.train import *
            random.seed(seed)
            np.random.seed(seed)
            torch.manual_seed(seed)
            torch.cuda.manual_seed(seed)
            torch.backends.cudnn.deterministic = True
            torch.backends.cudnn.benchmark = False
            os.environ['PYTHONHASHSEED'] = str(seed)

            version = 'nips_23'

            CONF = select_conf(dataset=dataset, version=version, seed=seed, method=method, hidden_dim=mthd_dt2hidden_dim[(method, dataset)])
            pid2model = train(CONF)
            print('end')
# Out:
# ############################### NBEATS #############################
# ----------------seed=1--dataset='shanghai_t1dm'------------------------
# global_loop: 100%|██████████| 20/20 [00:29<00:00,  1.46s/it]
#
#  Results after 20 global rounds of training:
# rmse, 14.87228, 3.03503
# mape, 9.93670, 3.84112
# mae, 11.66575, 2.78231
# grmse, 18.07486, 4.80848
# time_lag, -2.50000, 5.59017
# [11.723737220029152, 11.17363267423231, 12.514628890993807, 14.895629426142976, 21.588798076608576, 16.8292538575063, 12.68668697364239, 12.203676413998288, 16.639065177774693, 15.264597925562978, 14.010109112659787, 18.937533841244516]
# tune_loop: 0it [00:00, ?it/s]
#
#  Results after 0 of fine tuning:
# rmse, 14.87228, 3.03503
# mape, 9.93670, 3.84112
# mae, 11.66575, 2.78231
# grmse, 18.07486, 4.80848
# time_lag, -2.50000, 5.59017
# [11.723737220029152, 11.17363267423231, 12.514628890993807, 14.895629426142976, 21.588798076608576, 16.8292538575063, 12.68668697364239, 12.203676413998288, 16.639065177774693, 15.264597925562978, 14.010109112659787, 18.937533841244516]
# models have been saved...
# end
# ----------------seed=10--dataset='shanghai_t1dm'------------------------
# global_loop: 100%|██████████| 20/20 
/it]
#
#  Results after 30 of fine tuning:
# rmse, 20.22235, 2.58698
# mape, 9.66328, 1.77682
# mae, 14.15716, 1.72458
# grmse, 25.42026, 3.41337
# time_lag, -8.06250, 5.47544
# [19.25647656370286, 18.839670021099263, 17.471903889877296, 24.640674540216526, 18.692036055873167, 21.51827013742116, 23.25124954639535, 18.192694168092586, 17.68819099936673, 21.875087890448434, 24.0554943637006, 17.186454158521727]
# models have been saved...
# end
# ----------------seed=1--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 [01:09<00:00,  2.31s/it]
#
#  Results after 30 global rounds of training:
# rmse, 22.49594, 4.84233
# mape, 11.01230, 2.63187
# mae, 16.27128, 3.34759
# grmse, 28.16455, 6.78827
# time_lag, -11.97917, 6.31706
# [25.43993529113601, 21.333883437375654, 26.609153652558525, 15.172389421473333, 22.325778803211364, 24.930964251621415, 31.72750995107105, 19.51407995285071, 24.82349803487615, 17.877087024415236, 25.688132025375552, 14.508832674820448]
# tune_loop: 100%|██████████| 30/30 [02:19<00:00,  4.65s/it]
#
#  Results after 30 of fine tuning:
# rmse, 21.79916, 4.41488
# mape, 10.53394, 2.53290
# mae, 15.64911, 2.99864
# grmse, 27.61034, 6.08586
# time_lag, -11.49306, 6.41779
# [24.816815440609645, 20.721188316881634, 24.611718638403485, 14.927761334898133, 21.785795375128107, 23.96574500393739, 30.272671361273293, 19.57003180936432, 24.223352637244112, 17.644612972331227, 24.699822626751164, 14.35038759990747]
# models have been saved...
# end
# ----------------seed=10--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 [01:08<00:00,  2.30s/it]
#
#  Results after 30 global rounds of training:
# rmse, 22.12067, 4.72448
# mape, 10.93058, 2.63233
# mae, 16.06106, 3.26564
# grmse, 27.70125, 6.52408
# time_lag, -11.84028, 6.44029
# [24.830202182617995, 21.286316480009155, 25.33241042748215, 14.84734074579282, 22.290058550956704, 25.050393545748438, 31.28728537400167, 19.36006701497231, 24.568118940238765, 17.686443175969465, 24.768190423120085, 14.141157513281213]
# tune_loop: 100%|██████████| 30/30 [02:11<00:00,  4.40s/it]
#
#  Results after 30 of fine tuning:
# rmse, 21.76535, 4.49993
# mape, 10.54767, 2.61341
# mae, 15.65623, 3.06143
# grmse, 27.54611, 6.15768
# time_lag, -11.07639, 6.08690
# [24.839467496462408, 20.727145558139, 24.208248731385446, 14.781002244223833, 22.03152149655409, 24.202823644427962, 30.549967874113634, 19.380517580031807, 24.3587799097452, 17.577374983999317, 24.36584112784099, 14.161474076608725]
# models have been saved...
# end
# ----------------seed=20--dataset='arises'------------------------
# global_loop: 100%|██████████| 30/30 [01:05<00:00,  2.19s/it]
#
#  Results after 30 global rounds of training:
# rmse, 22.47129, 4.77028
# mape, 10.77204, 2.49244
# mae, 16.19081, 3.19023
# grmse, 28.48117, 6.69239
# time_lag, -12.29167, 6.36582
# [25.528810270135853, 21.800002575795432, 25.225800352376705, 15.039033076269918, 22.53991278725433, 25.265573061557625, 31.750917917033814, 19.90773778412908, 24.79006951153463, 18.201471055493958, 25.3752693951217, 14.230878348140367]
# tune_loop: 100%|██████████| 30/30 [02:05<00:00,  4.17s/it]
#
#  Results after 30 of fine tuning:
# rmse, 21